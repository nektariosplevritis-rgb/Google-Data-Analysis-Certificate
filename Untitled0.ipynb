# %% [markdown]
# <a href="https://colab.research.google.com/github/nektariosplevritis-rgb/Google-Data-Analysis-Certificate/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('2017_Yellow_Taxi_Trip_Data.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2801202201.py in <cell line: 0>()
#       3 import seaborn as sns
#       4
# ----> 5 df = pd.read_csv('2017_Yellow_Taxi_Trip_Data.csv')
#       6 df.head()
#
# ...

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['trip_distance'], bins=50, kde=True)
plt.title('Distribution of Trip Distance (miles)')
plt.xlabel('Distance')
plt.show()

# %%
sns.boxplot(x='payment_type', y='tip_amount', data=df)
plt.title('Tip Amount by Payment Type')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4064416070.py in <cell line: 0>()
# ----> 1 sns.boxplot(x='payment_type', y='tip_amount', data=df)
#       2 plt.title('Tip Amount by Payment Type')
#       3 plt.show()
#
# NameError: name 'df' is not defined
